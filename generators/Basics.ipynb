# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G_di = nx.DiGraph()
G_multi = nx.MultiGraph()
G_multi_di = nx.MultiDiGraph()

n = 150
m = 3
G_barabasi = nx.barabasi_albert_graph(n,m)
# Plot the graph
plt.figure(figsize=(12,8))
nx.draw(G_barabasi, node_size=10)
